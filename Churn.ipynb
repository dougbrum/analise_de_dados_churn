# %% [markdown]
# ## Análise de Dados com Python
# #### Desafio:
# Você trabalha em uma empresa de telecom e tem clientes de vários serviços diferentes, entre os principais: internet e telefone.
#
# O problema é que, analisando o histórico dos clientes dos últimos anos, você percebeu que a empresa está com Churn de mais de 26% dos clientes.
#
# Isso representa uma perda de milhões para a empresa.
#
# O que a empresa precisa fazer para resolver isso?
#
# Link Original do Kaggle: https://www.kaggle.com/radmirzosimov/telecom-users-dataset

# %% [markdown]
# # Importando Bibliotecas

# %%
import pandas as pd
import numpy as np
import plotly.express as px

# %% [markdown]
# # Importando base de dados

# %%
df = pd.read_csv('telecom_users.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    Unnamed: 0   IDCliente     Genero  Aposentado Casado Dependentes  \
# 0        1869  7010-BRBUU  Masculino           0    Sim         Sim
# 1        4528  9688-YGXVR   Feminino           0    Nao         Nao
# 2        6344  9286-DOJGF   Feminino           1    Sim         Nao
# 3        6739  6994-KERXL  Masculino           0    Nao         Nao
# 4         432  2181-UAESM  Masculino           0    Nao         Nao
#
#    MesesComoCliente ServicoTelefone MultiplasLinhas ServicoInternet  \
# 0                72             Sim             Sim             Nao
# 1                44             Sim             Nao           Fibra
# 2                38             Sim             Sim           Fibra
# 3                 4             Sim             Nao             DSL
# 4                 2             Sim             Nao             DSL
#
#   ServicoSegurancaOnline ServicoBackupOnline ProtecaoEquipamento  \
# 0            SemInternet         SemInternet         SemInternet
# 1                    Nao                 Sim                 Sim
# 2                    Nao                 Nao                 Nao
# 3                    Nao                 Nao                 Nao
# 4                    Sim                 Nao                 Sim
#
#   ServicoSuporteTecnico ServicoStreamingTV ServicoFilmes TipoContrato  \
# 0           SemInternet        SemInternet   SemInternet       2 anos
# 1                   Nao                Sim           Nao       Mensal
# 2                   Nao                Nao           Nao       Mensal
# 3                   Nao                Nao           Sim       Mensal
# 4                   Nao                Nao           Nao       Mensal
#
#   FaturaDigital    FormaPagamento  ValorMensal TotalGasto Churn  Codigo
# 0           Nao     CartaoCredito        24.10    1734.65   Nao     NaN
# 1           Sim     CartaoCredito        88.15     3973.2   Nao     NaN
# 2           Sim  DebitoAutomatico        74.95    2869.85   Sim     NaN
# 3           Sim  BoletoEletronico        55.90      238.5   Nao     NaN
# 4           Nao  BoletoEletronico        53.45      119.5   Nao     NaN

# %% [markdown]
# ## Visualizando os tipos de dados

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5986 entries, 0 to 5985
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Unnamed: 0              5986 non-null   int64
#  1   IDCliente               5986 non-null   object
#  2   Genero                  5986 non-null   object
#  3   Aposentado              5986 non-null   int64
#  4   Casado                  5986 non-null   object
#  5   Dependentes             5985 non-null   object
#  6   MesesComoCliente        5986 non-null   int64
#  7   ServicoTelefone         5986 non-null   object
#  8   MultiplasLinhas         5986 non-null   object
#  9   ServicoInternet         5986 non-null   object
#  10  ServicoSegurancaOnline  5986 non-null   object
#  11  ServicoBackupOnline     5986 non-null   object
#  12  ProtecaoEquipamento     5986 non-null   object
#  13  ServicoSuporteTecnico   5986 non-null   object
#  14  ServicoStreamingTV      5986 non-null   object
#  15  ServicoFilmes           5986 non-null   object
#  16  TipoContrato            5986 non-null   object
#  17  FaturaDigital           5986 non-null   object
#  18  FormaPagamento          5986 non-null   object
#  19  ValorMensal             5986 non-null   float64
#  20  TotalGasto              5986 non-null   object
#  21  Churn                   5985 non-null   object
#  22  Codigo                  0 non-null      float64
# dtypes: float64(2), int64(3), object(18)
# memory usage: 1.1+ MB

# %%
# Percentual de entradas vazias em cada coluna
(df.isnull().sum()/df['IDCliente'].count())*100
# Out:
# IDCliente                 0.0
# Genero                    0.0
# Aposentado                0.0
# Casado                    0.0
# Dependentes               0.0
# MesesComoCliente          0.0
# ServicoTelefone           0.0
# MultiplasLinhas           0.0
# ServicoInternet           0.0
# ServicoSegurancaOnline    0.0
# ServicoBackupOnline       0.0
# ProtecaoEquipamento       0.0
# ServicoSuporteTecnico     0.0
# ServicoStreamingTV        0.0
# ServicoFilmes             0.0
# TipoContrato              0.0
# FaturaDigital             0.0
# FormaPagamento            0.0
# ValorMensal               0.0
# TotalGasto                0.0
# Churn                     0.0
# dtype: float64

# %% [markdown]
# ## Tratando dados

# %% [markdown]
# **1)Ajustar os tipos de dados**
#
# A coluna TotalGasto, por exemplo, está como object porém é uma coluna com valores float64
#
# **2)Colunas vazias**
#
# É possível observar acima que a coluna Codigo tem 100% dos dados missing
#
# **3)Linhas com valores varios**
#
# Tanto a coluna Churn quanto a Dependentes possuem um valor faltante.

# %%
#1)
df['TotalGasto'] = pd.to_numeric(df['TotalGasto'], errors = 'coerce')

#2)
df = df.drop(['Unnamed: 0', 'Codigo'], axis = 1)

#3)Temos muito poucas entradas vazias. Dessa forma excluir uma linha de 5986 não causará impacto algum.
df = df.dropna(how = 'any', axis = 0)

# %% [markdown]
# ## Análise Inicial

# %%
df['Churn'].value_counts()
# Out:
# Nao    4387
# Sim    1587
# Name: Churn, dtype: int64

# %%
df['Churn'].value_counts(normalize =  True).map("{:.1%}".format)
# Out:
# Nao    73.4%
# Sim    26.6%
# Name: Churn, dtype: object

# %% [markdown]
# **De fato aproximadamente 27% dos 5985 clientes cancelaram os serviços da empresa nos últimos anos.**

# %% [markdown]
# ## Análise Gráfica

# %%
grafico = px.histogram(df, x = 'Genero', color = 'Churn')
grafico.show()
# Out:
# <div>                            <div id="9878d5a5-56f6-4214-85f4-43853ac8148c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9878d5a5-56f6-4214-85f4-43853ac8148c")) {                    Plotly.newPlot(                        "9878d5a5-56f6-4214-85f4-43853ac8148c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=Nao<br>Genero=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Nao","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Nao","offsetgroup":"Nao","orientation":"v","showlegend":true,"x":["Masculino","Feminino","Masculino","Masculino","Feminino","Feminino","Feminino","Masculino","Masculino","Masculino","Masculino","Masculino","Feminino","Masculino","Masculino","Masculino","Masculino","Feminino","Feminino","Feminino","Masculino","Masculino","Feminino","Masculino","Feminino","Feminino","Masculino","Feminino","Feminino","Feminino","Feminino","Feminino","Masculino","Masculino","Masculino","Feminino","Masculino","Feminino","Masculino","Feminino","Feminino","Masculino","Feminino","Feminino","Masculino","Masculino","Masculino","Feminino","Feminino","Feminino","Masculino","Feminino","Masculino","Feminino","Feminino","Masculino","Masculino","Feminino","Feminino","Masculino","Masculino","Masculino","Feminino","Masculino","Masculino","Feminino","Feminino","Masculino","Masculino","Feminino","Masculino","Feminino","Masculino","Feminino","Feminino","Feminino","Masculino","Feminino","Feminino","Masculino","Masculino","Feminino","Masculino","Masculino","Masculino","Masculino","Feminino","Feminino","Feminino","Feminino","Masculino","Masculino","Feminino","Masculino","Masculino","Feminino","Masculino","Masculino","Masculino","Feminino","Masculino","Masculino","Feminino","Feminino","Masculino","Feminino","Feminino","Masculino","Feminino","Masculino","Masculino","Masculino","Feminino","Masculino","Masculino","Masculino","Masculino","Masculino","Feminino","Feminino","Masculino","Feminino","Masculino","Masculino","Feminino","Masculino","Feminino","Feminino","Masculino","Masculino","Masculino","Masculino","Feminino","Masculino","Masculino","Feminino","Feminino","Feminino","Feminino","Feminino","Masculino","Masculino","Feminino","
im","Sim","Sim","Sim","SemInternet","Nao","Nao","Sim","Nao","Sim","Nao","Sim","SemInternet","Sim","SemInternet","Nao","Nao","SemInternet","SemInternet","Sim","Sim","Sim","SemInternet","Sim","Sim","SemInternet","SemInternet","SemInternet","Nao","Nao","Sim","Nao","Nao","SemInternet","Sim","Sim","Nao","Sim","Sim","Sim","Nao","Nao","Sim","SemInternet","Nao","Nao","SemInternet","Sim","SemInternet","Sim","SemInternet","Nao","Nao","Nao","Nao","Nao","Sim","Nao","Nao","Sim","SemInternet","SemInternet","Sim","Nao","SemInternet","SemInternet","Sim","SemInternet","SemInternet","Sim","Sim","Nao","Sim","Nao","Sim","Nao","Nao","Sim","Sim","Sim","Nao","SemInternet","Nao","Sim","SemInternet","Sim","Sim","Sim","SemInternet","Nao","Sim","Nao","N ...

# %%
grafico = px.histogram(df, x = 'TipoContrato', color = 'Churn')
grafico.show()
# Out:
# <div>                            <div id="aaf6f228-90d5-471e-8435-98d53e60abfe" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aaf6f228-90d5-471e-8435-98d53e60abfe")) {                    Plotly.newPlot(                        "aaf6f228-90d5-471e-8435-98d53e60abfe",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=Nao<br>TipoContrato=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Nao","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Nao","offsetgroup":"Nao","orientation":"v","showlegend":true,"x":["2 anos","Mensal","Mensal","Mensal","2 anos","Mensal","Mensal","Anual","Mensal","Anual","Mensal","Anual","Anual","Anual","Mensal","2 anos","2 anos","2 anos","2 anos","Mensal","2 anos","2 anos","Mensal","Anual","2 anos","Anual","Mensal","Mensal","Anual","Anual","Mensal","Mensal","Anual","2 anos","Mensal","2 anos","Mensal","2 anos","2 anos","Mensal","Mensal","Anual","Mensal","2 anos","Mensal","Anual","Mensal","2 anos","Anual","Mensal","2 anos","2 anos","Mensal","2 anos","Mensal","Anual","Anual","Mensal","2 anos","2 anos","2 anos","2 anos","2 anos","2 anos","Mensal","Mensal","2 anos","Mensal","Mensal","2 anos","Mensal","Mensal","Anual","Mensal","Anual","2 anos","2 anos","Anual","2 anos","2 anos","Anual","Mensal","Mensal","2 anos","2 anos","Mensal","Anual","Mensal","2 anos","Mensal","Mensal","Anual","2 anos","2 anos","2 anos","Mensal","Mensal","2 anos","Mensal","Mensal","Mensal","2 anos","2 anos","Anual","Anual","Mensal","2 anos","Anual","Mensal","Mensal","2 anos","2 anos","Anual","Anual","2 anos","2 anos","2 anos","Mensal","Mensal","Mensal","Anual","2 anos","Mensal","Mensal","Mensal","Anual","2 anos","2 anos","Mensal","2 anos","2 anos","Mensal","2 anos","Mensal","Anual","Mensal","Anual","Anual","2 anos","2 anos","Anual","2 anos","Mensal","2 anos","2 anos","2 anos","2 anos","Mensal","Mensal","2 anos","2 anos","2 anos","2 anos","Mensal","2 anos","Anual","Mensal","2 anos","Anual","2 anos","Anual","Mensal","Mensal","Mensal","Mensal","2 anos","Mensal","Mensal","Mensal","Mensal","2 anos","2 anos","Anual","2 anos","Anual","Anual","Mensal","Anual","Mensal","Anual","2 anos","2 anos","Mensal","Anual","Mensal","Anual","Mensal","2 anos","2 anos","2 anos","Mensal","Anual","Mensal","Mensal","Anual","Mensal","2 anos","Mensal","2 anos","2 anos","Mensal","2 anos","2 anos","Anual","2 anos","2 anos","Anual","Mensal","Mensal","Mensal","2 anos","Mensal","Mensal","Mensal","2 anos","Anual","2 anos","Anual","Mensal","Mensal","Anual","2 anos","Anual","2 anos","Mensal","Anual","Mensal","2 anos","Mensal","Mensal","Anual","Mensal","Mensal","Mensal","Mensal","2 anos","Mensal","Anual","Anual","Mensal","2 anos","Mensal","2 anos","Anual","2 anos","Anual","Mensal","Mensal","Mensal","2 anos","2 anos","Mensal","2 anos","Anual","2 anos","2 anos","Anual","Anual","2 anos","Anual","2 anos","Mensal","2 anos","2 anos","Anual","Mensal","Anual","Anual","2 anos","2 anos","Anual","2 anos","2 anos","Anual","Mensal","2 anos","2 anos","Anual","Anual","Anual","Mensal","2 anos","Anual","Mensal","Anual","Mensal","2 anos","2 anos","Mensal","Anual","Anual","Anual","Anual","2 anos","Mensal","Mensal","Mensal","Mensal","2 anos","Anual","Mensal","Mensal","Mensal","Anual","Anual","Anual","Anual","Mensal","Mensal","Mensal","Anual","Mensal","2 anos","2 anos","Mensal","2 anos","Mensal","Anual","2 anos","Mensal","2 anos","Mensal","2 anos","Anual","Mensal","2 anos","2 anos","2 anos","Mensal","2 anos","Mensal","Mensal","Mensal","2 anos","Mensal","Mensal","2 anos","Mensal","Mensal","Mensal","2 anos","2 anos","Mensal","Mensal","Mensal","Anual","2 anos","Mensal","Mensal","Mensal","2 anos","2 anos","Anual","Anual","2 anos","Anual","Mensal","Mensal","Mensal","Anual","Anual","2 anos","Mensal","2 anos","Anual","Mensal", ...

# %%
grafico = px.histogram(df, x = 'FormaPagamento', color = 'Churn')
grafico.show()
# Out:
# <div>                            <div id="084eb7d0-e146-4ef2-aaaf-7cc1a21f8656" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("084eb7d0-e146-4ef2-aaaf-7cc1a21f8656")) {                    Plotly.newPlot(                        "084eb7d0-e146-4ef2-aaaf-7cc1a21f8656",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Churn=Nao<br>FormaPagamento=%{x}<br>count=%{y}<extra></extra>","legendgroup":"Nao","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Nao","offsetgroup":"Nao","orientation":"v","showlegend":true,"x":["CartaoCredito","CartaoCredito","BoletoEletronico","BoletoEletronico","DebitoAutomatico","BoletoEletronico","BoletoImpresso","BoletoImpresso","BoletoEletronico","BoletoEletronico","BoletoEletronico","DebitoAutomatico","DebitoAutomatico","DebitoAutomatico","BoletoImpresso","CartaoCredito","DebitoAutomatico","DebitoAutomatico","DebitoAutomatico","BoletoImpresso","DebitoAutomatico","CartaoCredito","CartaoCredito","BoletoEletronico","BoletoImpresso","CartaoCredito","BoletoEletronico","BoletoEletronico","BoletoEletronico","BoletoImpresso","DebitoAutomatico","BoletoEletronico","CartaoCredito","BoletoEletronico","BoletoImpresso","DebitoAutomatico","BoletoImpresso","DebitoAutomatico","CartaoCredito","BoletoEletronico","BoletoEletronico","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoEletronico","BoletoImpresso","BoletoImpresso","CartaoCredito","CartaoCredito","BoletoImpresso","DebitoAutomatico","CartaoCredito","BoletoImpresso","BoletoEletronico","DebitoAutomatico","BoletoImpresso","DebitoAutomatico","CartaoCredito","BoletoEletronico","CartaoCredito","BoletoEletronico","DebitoAutomatico","BoletoEletronico","BoletoImpresso","BoletoImpresso","CartaoCredito","BoletoImpresso","BoletoEletronico","DebitoAutomatico","CartaoCredito","BoletoImpresso","DebitoAutomatico","BoletoImpresso","CartaoCredito","DebitoAutomatico","CartaoCredito","CartaoCredito","BoletoEletronico","BoletoEletronico","DebitoAutomatico","BoletoEletronico","CartaoCredito","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoEletronico","DebitoAutomatico","BoletoImpresso","DebitoAutomatico","BoletoImpresso","CartaoCredito","BoletoEletronico","CartaoCredito","CartaoCredito","CartaoCredito","DebitoAutomatico","BoletoImpresso","CartaoCredito","DebitoAutomatico","DebitoAutomatico","DebitoAutomatico","BoletoEletronico","DebitoAutomatico","DebitoAutomatico","BoletoImpresso","DebitoAutomatico","BoletoEletronico","CartaoCredito","CartaoCredito","BoletoImpresso","DebitoAutomatico","DebitoAutomatico","CartaoCredito","BoletoEletronico","CartaoCredito","CartaoCredito","CartaoCredito","BoletoImpresso","BoletoImpresso","BoletoEletronico","DebitoAutomatico","CartaoCredito","BoletoImpresso","BoletoImpresso","BoletoImpresso","BoletoImpresso","CartaoCredito","BoletoImpresso","DebitoAutomatico","BoletoEletronico","BoletoImpresso","BoletoEletronico","BoletoEletronico","BoletoImpresso","BoletoEletronico","CartaoCredito","CartaoCredito","CartaoCredito","DebitoAutomatico","DebitoAutomatico","DebitoAutomatico","CartaoCredito","CartaoCredito","BoletoEletronico","CartaoCredito","BoletoEletronico","DebitoAutomatico","CartaoCredito","CartaoCredito","BoletoImpresso","DebitoAutomatico","BoletoImpresso","BoletoEletronico","BoletoImpresso","BoletoEletronico","DebitoAutomatico","BoletoImpresso","BoletoImpresso","BoletoImpresso","DebitoAutomatico","BoletoImpresso","DebitoAutomatico","BoletoImpresso","BoletoImpresso","BoletoEletronico","DebitoAutomatico","CartaoCredito","DebitoAutomatico","BoletoEletronico","BoletoEletronico","DebitoAutomatico","BoletoEletronico","BoletoImpresso","CartaoCredito","DebitoAutomatico","CartaoCredito","DebitoAutomatic ...

# %% [markdown]
# # Conclusões e Ações

# %% [markdown]
# **1)O gênero do cliente não influencia no cancelamento do produto.**
#
# **2)Com base na análise dos gráficos de dependentes e casados, podemos observar que famílias maiores tendem a cancelar menos.**
#
#     -Oferecer mais planos família
#
# **3)A coluna MesesComoCliente mostra que quanto maior o tempo de desão do cliente menor a probabilidade dele cancelar**
#
#     -Talvez seja importante criar incentivos para novos clientes para que fiquem mais tempo com a empresa
#     -Verificar como está sendo a experiência incial do cliente na empresa, ela pode não estar sendo satisfatória
#     -Verificar se estamos captando os clientes com o perfil adequado ao da empresa.(Ações de Marketing como o não pagamento do primeiro mês pode atrair uma quantidade grande de clientes que no segundo mês saem, pois não desejam pagar).
#
# **4)Clientes que aderem ao serviço de Fibra tem um cancelamento muito alto**
#
#     -É necessário verificar qual é a relação
#
# **5)Clientes que não possuem serviço de suporte técnico tendem a cancelar mais.**
#
#     -Criar alguma ação que incentive a adesão a serviços de suporte técnico
#
# **6)Tipos de contrato mais longos tendem a ter baixo churn**
#
#     -Promover ações que incentivem a migração de clientes de contratos do tipo mensal pra anuais.
#
# **7)Clientes que optam por pagar através de boleto eletrônico tendem a cancelarmais.**
#
#     -Criar estratégias para migrar esses clientes para as demais formas ofertadas
